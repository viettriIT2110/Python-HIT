# %% [markdown]
# # Normal Data Distribution
# Trong chương trước, chúng ta đã học cách tạo một mảng hoàn toàn ngẫu nhiên, có kích thước nhất định và giữa hai giá trị đã cho.
#
# Trong chương này, chúng ta sẽ tìm hiểu cách tạo một mảng trong đó các giá trị được tập trung xung quanh một giá trị nhất định.
#
# Trong lý thuyết xác suất, loại phân phối dữ liệu này được gọi là phân phối dữ liệu thông thường hoặc phân phối dữ liệu Gaussian , sau nhà toán học Carl Friedrich Gauss, người đã đưa ra công thức phân phối dữ liệu này.

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [raw]
# Giải thích biểu đồ
#
# Chúng tôi sử dụng mảng từ numpy.random.normal() phương thức, với 100000 giá trị, để vẽ biểu đồ với 100 thanh.
#
# Chúng tôi xác định rằng giá trị trung bình là 5.0 và độ lệch chuẩn là 1.0.
#
# Có nghĩa là các giá trị nên được tập trung xung quanh 5.0 và hiếm khi cách xa giá trị trung bình hơn 1.0.
#
# Và như bạn có thể thấy từ biểu đồ, hầu hết các giá trị nằm trong khoảng từ 4.0 đến 6.0, với đỉnh ở mức xấp xỉ 5.0.

# %% [markdown]
# # Scatter Plot
#
# Biểu đồ phân tán là một sơ đồ trong đó mỗi giá trị trong tập dữ liệu được biểu thị bằng một dấu chấm.
#
# Mô-đun Matplotlib có một phương pháp để vẽ các biểu đồ phân tán, nó cần hai mảng có cùng độ dài, một cho các giá trị của trục x và một cho các giá trị của trục y:
#
# Giả sử:
#
# Các x mảng đại diện cho tuổi của mỗi chiếc xe.
#
# Các y mảng đại diện cho tốc độ của mỗi chiếc xe.

# %%
# sử dụng scatter() để vẽ biểu đồ
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Phân phối dữ liệu ngẫu nhiên
# Trong Machine Learning, các bộ dữ liệu có thể chứa hàng ngàn, hoặc thậm chí hàng triệu giá trị.
#
# Bạn có thể không có dữ liệu trong thế giới thực khi bạn đang kiểm tra thuật toán, bạn có thể phải sử dụng các giá trị được tạo ngẫu nhiên.
#
# Như chúng ta đã học ở chương trước, mô-đun NumPy có thể giúp chúng ta điều đó!
#
# Chúng ta hãy tạo hai mảng chứa đầy 1000 số ngẫu nhiên từ một phân phối dữ liệu bình thường.
#
# Mảng đầu tiên sẽ có giá trị trung bình được đặt thành 5.0 với độ lệch chuẩn là 1.0.
#
# Mảng thứ hai sẽ có giá trị trung bình được đặt thành 10.0 với độ lệch chuẩn là 2.0:

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %% [raw]
# Giải thích âm mưu
# Chúng ta có thể thấy rằng các chấm được tập trung xung quanh giá trị 5 trên trục x và 10 trên trục y.
#
# Chúng ta cũng có thể thấy rằng mức chênh lệch rộng hơn trên trục y so với trục x

# %% [markdown]
# # Linear Regression (Hồi quy tuyến tính)
#
# Thuật ngữ hồi quy được sử dụng khi bạn cố gắng tìm mối quan hệ giữa các biến.
#
# Trong Machine Learning và trong mô hình thống kê, mối quan hệ đó được sử dụng để dự đoán kết quả của các sự kiện trong tương lai.
#
# - Hồi quy tuyến tính :
#
# Hồi quy tuyến tính sử dụng mối quan hệ giữa các điểm dữ liệu để vẽ một đường thẳng đi qua tất cả chúng.
#
# Dòng này có thể được sử dụng để dự đoán các giá trị trong tương lai.
#
# Làm thế nào nó hoạt động?
#
# Python có các phương thức để tìm mối quan hệ giữa các điểm dữ liệu và để vẽ một đường hồi quy tuyến tính. Chúng tôi sẽ chỉ cho bạn cách sử dụng các phương pháp này thay vì đi qua công thức toán học.
#
# Trong ví dụ dưới đây, trục x biểu thị tuổi và trục y biểu thị tốc độ. Chúng tôi đã đăng ký tuổi và tốc độ của 13 chiếc xe khi chúng đang đi qua một trạm thu phí. Hãy cho chúng tôi xem liệu dữ liệu chúng tôi thu thập có thể được sử dụng trong hồi quy tuyến tính hay không:

# %%
# Bắt đầu bằng cách vẽ một biểu đồ phân tán:
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [raw]
# Import scipyvà vẽ đường hồi quy tuyến tính:

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# ###### Giải thích:

# %% [raw]
# Nhập các mô-đun bạn cần:

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %% [raw]
# Tạo các mảng biểu thị các giá trị của trục x và y:

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %% [raw]
# Thực hiện một phương thức trả về một số giá trị quan trọng của hồi quy tuyến tính:

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %% [raw]
# Tạo một hàm sử dụng slopevà interceptcác giá trị để trả về một giá trị mới.
#
# Giá trị mới này biểu thị vị trí trên trục y, giá trị x tương ứng sẽ được đặt:

# %%
def myfunc(x):
  return slope * x + intercept

# %% [markdown]
# Chạy từng giá trị của mảng x thông qua hàm. Điều này sẽ dẫn đến một mảng mới với các giá trị mới cho trục y:

# %%
mymodel = list(map(myfunc, x))

# %% [raw]
# Vẽ sơ đồ phân tán ban đầu:

# %%
plt.scatter(x, y)

# %% [raw]
# Vẽ đường hồi quy tuyến tính:

# %%
plt.plot(x, mymodel)

# %%
# hiện thị sơ đồ
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %% [markdown]
# ## R-Squared
# Điều quan trọng là phải biết mối quan hệ giữa các giá trị của trục x và giá trị của trục y là như thế nào, nếu không có mối quan hệ nào thì không thể sử dụng hồi quy tuyến tính để dự đoán bất cứ điều gì.
#
# Mối quan hệ được đo bằng một giá trị gọi là bình phương r.
#
# Giá trị r bình phương nằm trong khoảng từ 0 đến 1, trong đó 0 có nghĩa là không có mối quan hệ nào và 1 có nghĩa là 100% liên quan.
#
# Python và mô-đun Scipy sẽ tính toán giá trị này cho bạn, tất cả những gì bạn phải làm là cung cấp nó với các giá trị x và y:

# %% [raw]
# Làm thế nào tốt dữ liệu của tôi phù hợp trong một hồi quy tuyến tính?

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r)
# Out:
# -0.758591524376155

# %% [raw]
# Lưu ý: Kết quả -076 cho thấy có một mối quan hệ, không hoàn hảo, nhưng nó chỉ ra rằng chúng ta có thể sử dụng hồi quy tuyến tính trong các dự đoán trong tương lai.

# %% [markdown]
# ## Predict Future Values (Dự đoán giá trị tương lai)
#
# Bây giờ chúng tôi có thể sử dụng thông tin chúng tôi đã thu thập để dự đoán các giá trị trong tương lai.
#
# Ví dụ: Chúng ta hãy cố gắng dự đoán tốc độ của một chiếc xe 10 tuổi.
#
# Để làm như vậy, chúng ta cần myfunc()chức năng tương tự từ ví dụ trên:

# %% [raw]
# Dự đoán tốc độ của một chiếc xe 10 tuổi:

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ## Bad Fit?
# Chúng ta hãy tạo một ví dụ trong đó hồi quy tuyến tính sẽ không phải là phương pháp tốt nhất để dự đoán các giá trị trong tương lai.
# Bạn sẽ nhận được một giá trị r bình phương rất thấp.

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)
# kết quả r-squared
print("kết quả ", r)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# kết quả  0.01331814154297491
